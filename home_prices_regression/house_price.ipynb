# %%
import pandas as pd
import numpy as np

# %%
# Load the data 
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
print ("Train data shape:", train.shape)
print ("Test data shape:", test.shape)
# Out:
# ('Train data shape:', (1460, 81))
# ('Test data shape:', (1459, 80))

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use(style='ggplot')
# Set the default size
plt.rcParams['figure.figsize'] = (10, 6)

# %%
# Try to predict SalePrice - target variable
# Get more information about Saleprice
train.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
print ("Skew is:", train.SalePrice.skew())
plt.hist(train.SalePrice)
plt.show()
# Out:
# ('Skew is:', 1.8828757597682129)

# %%
# transform SalePrice in logscale
target = np.log(train.SalePrice)
print ("Skew is:", target.skew())
plt.hist(target, color='blue')
plt.show()
# Out:
# ('Skew is:', 0.12133506220520406)

# %%
# check the types of the feature
numeric_features = train.select_dtypes(include=[np.number])
numeric_features.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# ...

# %%
# Check the correlation between the columns
corr = numeric_features.corr()

print (corr['SalePrice'].sort_values(ascending=False)[:5], '\n')
print (corr['SalePrice'].sort_values(ascending=False)[-5:])
# Out:
# (SalePrice      1.000000
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# Name: SalePrice, dtype: float64, '\n')
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %% [markdown]
# The first five features are most positively correlated with SalePrice, the second five are the most negatively correlated

# %%
# Get the unique values of OverallQual
train.OverallQual.unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2])

# %%
# Create a pivot table 
quality_pivot = train.pivot_table(index='OverallQual', values='SalePrice', aggfunc=np.median)

# %%
quality_pivot
# Out:
# OverallQual
# 1      50150
# 2      60000
# 3      86250
# 4     108000
# 5     133000
# 6     160000
# 7     200141
# 8     269750
# 9     345000
# 10    432390
# Name: SalePrice, dtype: int64

# %%
# Create a chart
quality_pivot.plot(kind='bar')
plt.xlabel('Overall Quality')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %%
# Create a scatter plot to visualize the relationship between the Ground Living Area and SalePrice
plt.scatter(x=train['GrLivArea'], y=target)
plt.ylabel('Sale Price')
plt.xlabel('Above grade (ground) living area square feet')
plt.show()

# %%
# Do same thing with GarageArea
plt.scatter(x=train['GarageArea'], y=target)
plt.ylabel('Sale Price')
plt.xlabel('GarageArea')
plt.show()

# %%
# Create a new dataframe with some outliers removed
train = train[train['GarageArea'] < 1200]

# %%
plt.scatter(x=train['GarageArea'], y=np.log(train.SalePrice))
plt.ylabel('Sale Price')
plt.xlabel('GarageArea')
plt.show()

# %%
# Counting the Null Values
nulls = pd.DataFrame(train.isnull().sum().sort_values(ascending=False)[:25])
nulls.columns = ['Null Count']
nulls.index.name = 'Feature'
nulls
# Out:
#               Null Count
# Feature
# PoolQC              1449
# MiscFeature         1402
# Alley               1364
# Fence               1174
# FireplaceQu          689
# LotFrontage          258
# GarageCond            81
# GarageType            81
# GarageYrBlt           81
# GarageFinish          81
# GarageQual            81
# BsmtExposure          38
# BsmtFinType2          38
# BsmtFinType1          37
# BsmtCond              37
# BsmtQual              37
# MasVnrArea             8
# MasVnrType             8
# Electrical             1
# Utilities              0
# YearRemodAdd           0
# MSSubClass             0
# Foundation             0
# ExterCond              0
# ExterQual              0

# %%
print ("Unique values are:", train.MiscFeature.unique())
# Out:
# ('Unique values are:', array([nan, 'Shed', 'Gar2', 'Othr', 'TenC'], dtype=object))

# %%
# Check non-numeric features
categoricals = train.select_dtypes(exclude=[np.number])
categoricals.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1455   1455    91     1455        1455      1455      1455
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1147   1450    50      921        1309      1454      1048
#
#        LandSlope Neighborhood Condition1      ...      GarageType  \
# count       1455         1455       1455      ...            1374
# unique         3           25          9      ...               6
# top          Gtl        NAmes       Norm      ...          Attchd
# freq        1378          225       1257      ...             867
#
#        GarageFinish GarageQual GarageCond PavedDrive PoolQC  Fence  \
# count          1374       1374       1374       1455      6    281
# unique            3          5          5          3      3      4
# top             Unf         TA         TA          Y     Ex  MnPrv
# ...

# %% [markdown]
# count: indicate the count of non-null observations
#
# unique: count the number of unique values
#
# top: the most commonly occurring value
#
# freq: the frequency of the top value

# %%
print ("Original: \n")
print (train.Street.value_counts(), "\n")
# Out:
# Original:
#
# (Pave    1450
# Grvl       5
# Name: Street, dtype: int64, '\n')

# %%
# Transform features into nummerical data
train['enc_street'] = pd.get_dummies(train.Street, drop_first=True)
test['enc_street'] = pd.get_dummies(train.Street, drop_first=True)

# %%
print ('Encoded: \n')
print (train.enc_street.value_counts())
# Out:
# Encoded:
#
# 1    1450
# 0       5
# Name: enc_street, dtype: int64

# %%
# Draw a pivot table for saleCondition
condition_pivot = train.pivot_table(index='SaleCondition', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar')
plt.xlabel('Sale Condition')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %%
# Set Patrial to 1 and otherwise to 0
def encode(x): return 1 if x == 'Partial' else 0
train['enc_condition'] = train.SaleCondition.apply(encode)
test['enc_condition'] = test.SaleCondition.apply(encode)

# %%
# Draw a pivot table for saleCondition
condition_pivot = train.pivot_table(index='enc_condition', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar')
plt.xlabel('Encoded Sale Condition')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %%
# Draw a pivot table for GarageType
condition_pivot = train.pivot_table(index='GarageType', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar')
plt.xlabel('GarageType')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %%
# Set Builtin to 1 and otherwise to 0
def encode(x): return 1 if x == 'BuiltIn' else 0
train['enc_garagetype'] = train.GarageType.apply(encode)
test['enc_garagetype'] = test.GarageType.apply(encode)

# %%
# Draw a pivot table for GarageType
condition_pivot = train.pivot_table(index='enc_garagetype', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar')
plt.xlabel('enc_garagetype')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %%
# Draw a pivot table for Fence
condition_pivot = train.pivot_table(index='Fence', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar')
plt.xlabel('Fence')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %%
# Set NA to 1 and otherwise to 0
def encode(x): return 1 if x == 0 else 0
train['enc_fence'] = train.Fence.fillna(0).apply(encode)
test['enc_fence'] = test.Fence.fillna(0).apply(encode)

# %%
# Draw a pivot table for Fence
condition_pivot = train.pivot_table(index='enc_fence', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar')
plt.xlabel('enc_fence')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %%
data = train.select_dtypes(include=[np.number]).interpolate().dropna() 
sum(data.isnull().sum() != 0)
# Out:
# 0

# %%
list(data)
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice',
#  'enc_street',
#  'enc_condition',
#  'enc_garagetype',
#  'enc_fence']

# %%
# assign the features to X and the target variable to 
y = np.log(train.SalePrice)
x = data.drop(['SalePrice', 'Id'], axis = 1)

# %%
# Split data into train and test data
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, test_size=.33)

# %%
# Modelling using linear regression model
from sklearn import linear_model
# Create classifier 
lr = linear_model.LinearRegression()

# %%
# Fit the data
model = lr.fit(x_train, y_train)

# %%
# Evaluate the performance by checking r-squared
print "R^2 is: \n", model.score(x_test, y_test)
# Out:
# R^2 is:
# 0.889134400109

# %%
predictions = model.predict(x_test)

# %%
# RMSE: Root mean squared error
from sklearn.metrics import mean_squared_error
print 'RMSE is: \n', mean_squared_error(y_test, predictions)
# Out:
# RMSE is:
# 0.0177002397979

# %%
plt.scatter(predictions, y_test, alpha=0.75)
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.title('Linear Regress Model')
plt.show()

# %%
# Improve the performance by Ridge Regularization
for i in range (-2, 3):
    alpha = 10**i
    rm = linear_model.Ridge(alpha=alpha)
    ridge_model = rm.fit(x_train, y_train)
    preds_ridge = ridge_model.predict(x_test)
    
    plt.scatter(preds_ridge, y_test, alpha=.75, color='b')
    plt.xlabel('Predicted Price')
    plt.ylabel('Actual Price')
    plt.title('Ridge Regularization with alpha = {}'.format(alpha))
    overlay = 'R^2 is: {}\nRMSE is: {}'.format(
                    ridge_model.score(x_test, y_test),
                    mean_squared_error(y_test, preds_ridge))
    plt.annotate(s=overlay,xy=(12.1,10.6),size='x-large')
    plt.show()

# %%
rm = linear_model.Ridge(alpha=0.1)
ridge_model = rm.fit(x_train, y_train)
preds_ridge = ridge_model.predict(x_test)

# %%
mean_squared_error(y_test, preds_ridge)
# Out:
# 0.017697008513482972

# %%
from sklearn.ensemble import RandomForestRegressor
RFR = RandomForestRegressor(random_state = 42)
RFR_model = RFR.fit(x_train, y_train)
preds_RFR = RFR_model.predict(x_test)

# %%
mean_squared_error(y_test, preds_RFR)
# Out:
# 0.021336045481423212

# %%
# Make a submission
submission = pd.DataFrame()
submission['Id'] = test.Id

# %%
feats = test.select_dtypes(include=[np.number]).drop(['Id'], axis=1).interpolate()

# %%
predictions1 = ridge_model.predict(feats)

# %%
final_predictions1 = np.exp(predictions1)

# %%
predictions2 = model.predict(feats)

# %%
final_predictions2 = np.exp(predictions2)

# %%
submission['SalePrice1'] = final_predictions1

# %%
submission['SalePrice2'] = final_predictions2

# %%
submission['SalePrice'] = (submission['SalePrice1'] + submission['SalePrice2']) / 2

# %%
submission.head()
# Out:
#      Id      SalePrice     SalePrice1     SalePrice2
# 0  1461  127814.536785  127808.257221  127820.816350
# 1  1462  125727.082457  125678.575289  125775.589624
# 2  1463  174217.998284  174215.190218  174220.806349
# 3  1464  201124.076390  201120.394102  201127.758677
# 4  1465  181753.851933  181741.877442  181765.826425

# %%
del submission['SalePrice1']
del submission['SalePrice2']
submission.head()
# Out:
#      Id      SalePrice
# 0  1461  127814.536785
# 1  1462  125727.082457
# 2  1463  174217.998284
# 3  1464  201124.076390
# 4  1465  181753.851933

# %%
submission.to_csv('submission4.csv', index=False)
